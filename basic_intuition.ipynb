# %% [markdown]
# # Intuition for Random Average Consensus under Various Parameters

# %% [markdown]
# Descriptive text to be added

# %%
import matplotlib
import matplotlib.pyplot as plt

from basic_experiment import run_simulation

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Play Yourself

# %%
no_agents = 200
graph_size = 1000 # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate = 1 # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'single'

run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
# Out:
# Initial mean and standard deviation in values are (0.786, 9.177)
# Final mean and standard deviation in values are (0.786, 0.000)

# %% [markdown]
# ## Number of agents

# %%
no_agents_list = [20, 200, 2000]
graph_size = 1000 # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate = 1 # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for no_agents in no_agents_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
    plt.plot(std_rt_t, std_rt_val, label='{} agents'.format(no_agents))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()

# %% [markdown]
# ## Graph Size

# %%
no_agents = 200
graph_size_list = [100, 1000, 10000] # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate = 1 # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for graph_size in graph_size_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
    plt.plot(std_rt_t, std_rt_val, label='{} nodes'.format(graph_size))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()

# %% [markdown]
# ## Graph Density

# %%
no_agents = 200
graph_size = 1000 # n
edge_probability_list = [0.1, 0.5, 0.9] # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate = 1 # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for edge_probability in edge_probability_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
    plt.plot(std_rt_t, std_rt_val, label='{} edge_probability'.format(edge_probability))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()

# %% [markdown]
# ## Initial Standard Deviation of Values to be Averaged

# %%
no_agents = 200
graph_size = 1000 # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma_list = [1, 10, 100] # gaussian noise
clock_rate = 1 # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for sigma in sigma_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
    plt.plot(std_rt_t, std_rt_val, label='{} initial standard deviation'.format(sigma))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()

# %% [markdown]
# ## Clock Rate

# %%
no_agents = 200
graph_size = 1000 # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate_list = [0.1, 1, 10] # Poisson process for asynchronous agent actions
simulation_time = 100
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for clock_rate in clock_rate_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type)
    plt.plot(std_rt_t, std_rt_val, label='clock rate of {}'.format(clock_rate))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()

# %% [markdown]
# ## Communication Protocol

# %%
no_agents = 200
graph_size = 20 # n
edge_probability = 0.5 # p
mu = 0 # average value
sigma = 10 # gaussian noise
clock_rate = 0.01 # Poisson process for asynchronous agent actions
simulation_time = 1000
comm_limit_list = [1, 2, 5, no_agents-1]
parameter_type = 'sweep'

plt.figure(figsize=(10,5))
for comm_limit in comm_limit_list:
    (std_rt_val, std_rt_t) = run_simulation(no_agents, graph_size, edge_probability, mu, sigma, clock_rate, simulation_time, parameter_type, comm_limit)
    plt.plot(std_rt_t, std_rt_val, label='interact with up to {} neighbor(s)'.format(comm_limit))
plt.xlabel('Simulation time [s]', fontsize='large', fontweight='bold')
plt.ylabel('Standard deviation [-]', fontsize='large', fontweight='bold')
plt.legend()
plt.grid('k')
plt.show()
